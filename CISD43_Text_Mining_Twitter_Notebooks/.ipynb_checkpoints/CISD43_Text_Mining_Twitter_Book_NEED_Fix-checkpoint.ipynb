# %% [markdown]
# **Mining Twitter**
# - Reference Chapter 1 of Mining the Social Web, 3rd Edition
# - Safari books online library
#
# **Note**
# **Some of the code snippets in the book got depreciated
# Fixes has been done in this example**
#
# - Twitter implements OAuth 1.0A as its standard authentication mechanism, and in order to use it to make requests to Twitter's API, you'll need to go to https://developer.twitter.com/en/apps and create a sample application.
# - It is possible that Twitter no longer supports sandboxed applications and you may need to submit a request for permission to develop an app on Twitter.
# - There are four primary identifiers you'll need to note for an OAuth 1.0A workflow: consumer key, consumer secret, access token, and access token secret.
# - Note that you will need an ordinary Twitter account in order to login, create an app, and get these credentials.
#
# <img src="images/Twitter-AppCredentials.png" width="600px">
#
# - Please do not use the access token provided below those are mine.
# - You need to use yours.

# %% [markdown]
# - pip install tweepy

# %% [markdown]
# ## Authorizing an application to access Twitter account data

# %%
#import libraries that you need
import tweepy
from tweepy import OAuthHandler, Stream

# Go to https://developer.twitter.com/en/apps to create an app and get values
# for these credentials, which you'll need to provide in place of these
# empty string values that are defined as placeholders.
# See https://developer.twitter.com/en/docs/basics/authentication/overview/oauth
# for more information on Twitter's OAuth implementation.

access_token = '1219125691028930560-CZyXhFlgCpMM8rG11KwuYJaMoX7uNa'
access_secret = '0qSAxEoLmH9pKDPVFy2pQzbloaGxRcbb0JJgnkhq5F2d4'
consumer_key = 'HpU6B5BVTuwAfa5nYX1vAVxgD'
consumer_secret = 'Cgcs5YIHpIp5Pu5US3N0XAX8N4jlJgPQrE4aK8LYkM89nqeTQa'


auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_secret)
 
twitter_api = tweepy.API(auth)



# Nothing to see by displaying twitter_api except that it's now a
# defined variable

print(twitter_api)
# Out:
# <tweepy.api.API object at 0x0000024E24C37808>

# %% [markdown]
# **Very import links**
# - http://docs.tweepy.org/en/v3.5.0/api.html#API.trends_place

# %% [markdown]
# **Example 1-2. Retrieving trends**

# %% [markdown]
# **Exploring Trending Topics**
# - We are going to Twitter for the topics that are currently trending worldwide, but keep in mind that the API can easily be parameterized to constrain the topics to more specific locales if you feel inclined to try out some of the possibilities.
# - The device for constraining queries is via Yahoo! GeoPlanet’s Where On Earth (WOE) ID system, which is an API unto itself that aims to provide a way to map a unique identifier to any named place on Earth (or theoretically, even in a virtual world).
# - We are going to collect a set of trends for both the entire world and just the United States.

# %%
# The Yahoo! Where On Earth ID for the entire world is 1.
# See https://developer.twitter.com/en/docs/trends/locations-with-trending-topics/api-reference/get-trends-available

WORLD_WOE_ID = 1
US_WOE_ID = 23424977


# Prefix ID with the underscore for query string parameterization.
# Without the underscore, the twitter package appends the ID value
# to the URL itself as a special case keyword argument.

world_trends = twitter_api.trends_place(id=WORLD_WOE_ID)
us_trends = twitter_api.trends_place(id=US_WOE_ID)

print(world_trends)
print("*******************")
print(us_trends)
# Out:
# [{'trends': [{'name': '#LIVEDOJAO', 'url': 'http://twitter.com/search?q=%23LIVEDOJAO', 'promoted_content': None, 'query': '%23LIVEDOJAO', 'tweet_volume': 385291}, {'name': '#فحص_كورونا', 'url': 'http://twitter.com/search?q=%23%D9%81%D8%AD%D8%B5_%D9%83%D9%88%D8%B1%D9%88%D9%86%D8%A7', 'promoted_content': None, 'query': '%23%D9%81%D8%AD%D8%B5_%D9%83%D9%88%D8%B1%D9%88%D9%86%D8%A7', 'tweet_volume': 19057}, {'name': 'Beyoncé', 'url': 'http://twitter.com/search?q=Beyonc%C3%A9', 'promoted_content': None, 'query': 'Beyonc%C3%A9', 'tweet_volume': 872767}, {'name': '#AEWDynamite', 'url': 'http://twitter.com/search?q=%23AEWDynamite', 'promoted_content': None, 'query': '%23AEWDynamite', 'tweet_volume': 15114}, {'name': '#DireitaQuerImpeachment', 'url': 'http://twitter.com/search?q=%23DireitaQuerImpeachment', 'promoted_content': None, 'query': '%23DireitaQuerImpeachment', 'tweet_volume': 33792}, {'name': '#LiveSomdoReino', 'url': 'http://twitter.com/search?q=%23LiveSomdoReino', 'promoted_content': None, 'query': '%23LiveSomdoReino', 'tweet_volume': 14613}, {'name': 'Nicki', 'url': 'http://twitter.com/search?q=Nicki', 'promoted_content': None, 'query': 'Nicki', 'tweet_volume': 230734}, {'name': 'Vanoli', 'url': 'http://twitter.com/search?q=Vanoli', 'promoted_content': None, 'query': 'Vanoli', 'tweet_volume': 12385}, {'name': 'Ben Shapiro', 'url': 'http://twitter.com/search?q=%22Ben+Shapiro%22', 'promoted_content': None, 'query': '%22Ben+Shapiro%22', 'tweet_volume': 32603}, {'name': 'Amaia', 'url': 'http://twitter.com/search?q=Amaia', 'promoted_content': None, 'query': 'Amaia', 'tweet_volume': 24845}, {'name': 'Paris 6', 'url': 'http://twitter.com/search?q=%22Paris+6%22', 'promoted_content': None, 'query': '%22Paris+6%22', 'tweet_volume': None}, {'name': 'MIYAVI', 'url': 'http://twitter.com/search?q=MIYAVI', 'promoted_content': None, 'query': 'MIYAVI', 'tweet_volume': None}, {'name': 'OUÇA AUDIO DE DESCULPAS', 'url': 'http://twitter.com/search?q=%22OU%C3%87A+AUDIO+DE+DESCULPAS%22', 'promoted_content': None, 'query': '%22OU%C3%87A+AUDIO+DE+DESCULPAS%22', 'tweet_volume': 41436}, {'name': '平成最後の日', 'url': 'http://twitter.com/search?q=%E5%B9%B3%E6%88%90%E6%9C%80%E5%BE%8C%E3%81%AE%E6%97%A5', 'promoted_content': None, 'query': '%E5%B9%B3%E6%88%90%E6%9C%80%E5%BE%8C%E3%81%AE%E6%97%A5', 'tweet_volume': None}, {'name': 'JOAQUÍN EN RAZE', 'url': 'http://twitter.com/search?q=%22JOAQU%C3%8DN+EN+RAZE%22', 'promoted_content': None, 'query': '%22JOAQU%C3%8DN+EN+RAZE%22', 'tweet_volume': 58219}, {'name': 'General Flynn', 'url': 'http://twitter.com/search?q=%22General+Flynn%22', 'promoted_content': None, 'query': '%22General+Flynn%22', 'tweet_volume': 132992}, {'name': '87 in Lagos', 'url': 'http://twitter.com/search?q=%2287+in+Lagos%22', 'promoted_content': None, 'query': '%2287+in+Lagos%22', 'tweet_volume': None}, {'name': 'AGUANTE LALI CARETAS', 'url': 'http://twitter.com/search?q=%22AGUANTE+LALI+CARETAS%22', 'promoted_content': None, 'query': '%22AGUANTE+LALI+CARETAS%22', 'tweet_volume': 15259}, {'name': '#TheMaskedSinger', 'url': 'http://twitter.com/search?q=%23TheMaskedSinger', 'promoted_content': None, 'query': '%23TheMaskedSinger', 'tweet_volume': 12959}, {'name': '#Survivor40', 'url': 'http://twitter.com/search?q=%23Survivor40', 'promoted_content': None, 'query': '%23Survivor40', 'tweet_volume': None}, {'name': '#savageremix', 'url': 'http://twitter.com/search?q=%23savageremix', 'promoted_content': None, 'query': '%23savageremix', 'tweet_volume': 125134}, {'name': '#WWENXT', 'url': 'http://twitter.com/search?q=%23WWENXT', 'promoted_content': None, 'query': '%23WWENXT', 'tweet_volume': 10230}, {'name': '#١_مايو', 'url': 'http://twitter.com/search?q=%23%D9%A1_%D9%85%D8%A7%D9%8A%D9%88', 'promoted_content': None, 'query': '%23%D9%A1_%D9%85%D8%A7%D9%8A%D9%88', 'tweet_volume': None}, {'name': '#hobicult', 'url': 'http://twitter.com/search?q=%23hobicult', 'promoted_content': None, 'query': '%23hobicult', 'tweet_volume': 21048}, {'name': '#LiveMeB', 'url': 'h ...
# *******************
# [{'trends': [{'name': 'Beyoncé', 'url': 'http://twitter.com/search?q=Beyonc%C3%A9', 'promoted_content': None, 'query': 'Beyonc%C3%A9', 'tweet_volume': 878117}, {'name': '#TheMaskedSinger', 'url': 'http://twitter.com/search?q=%23TheMaskedSinger', 'promoted_content': None, 'query': '%23TheMaskedSinger', 'tweet_volume': 13614}, {'name': '#AEWDynamite', 'url': 'http://twitter.com/search?q=%23AEWDynamite', 'promoted_content': None, 'query': '%23AEWDynamite', 'tweet_volume': 16383}, {'name': '#Survivor', 'url': 'http://twitter.com/search?q=%23Survivor', 'promoted_content': None, 'query': '%23Survivor', 'tweet_volume': 15416}, {'name': '#TheChallenge35', 'url': 'http://twitter.com/search?q=%23TheChallenge35', 'promoted_content': None, 'query': '%23TheChallenge35', 'tweet_volume': None}, {'name': '#WWENXT', 'url': 'http://twitter.com/search?q=%23WWENXT', 'promoted_content': None, 'query': '%23WWENXT', 'tweet_volume': 11279}, {'name': 'Nicki', 'url': 'http://twitter.com/search?q=Nicki', 'promoted_content': None, 'query': 'Nicki', 'tweet_volume': 232232}, {'name': 'Flynn', 'url': 'http://twitter.com/search?q=Flynn', 'promoted_content': None, 'query': 'Flynn', 'tweet_volume': 473770}, {'name': 'Ben Shapiro', 'url': 'http://twitter.com/search?q=%22Ben+Shapiro%22', 'promoted_content': None, 'query': '%22Ben+Shapiro%22', 'tweet_volume': 33018}, {'name': 'Harrison Ford', 'url': 'http://twitter.com/search?q=%22Harrison+Ford%22', 'promoted_content': None, 'query': '%22Harrison+Ford%22', 'tweet_volume': None}, {'name': 'Mauricio', 'url': 'http://twitter.com/search?q=Mauricio', 'promoted_content': None, 'query': 'Mauricio', 'tweet_volume': 47878}, {'name': 'Kendall Jenner', 'url': 'http://twitter.com/search?q=%22Kendall+Jenner%22', 'promoted_content': None, 'query': '%22Kendall+Jenner%22', 'tweet_volume': 18131}, {'name': 'Linkin Park', 'url': 'http://twitter.com/search?q=%22Linkin+Park%22', 'promoted_content': None, 'query': '%22Linkin+Park%22', 'tweet_volume': 23604}, {'name': 'Parscale', 'url': 'http://twitter.com/search?q=Parscale', 'promoted_content': None, 'query': 'Parscale', 'tweet_volume': 27492}, {'name': 'Telvin Smith', 'url': 'http://twitter.com/search?q=%22Telvin+Smith%22', 'promoted_content': None, 'query': '%22Telvin+Smith%22', 'tweet_volume': None}, {'name': 'Led Zeppelin', 'url': 'http://twitter.com/search?q=%22Led+Zeppelin%22', 'promoted_content': None, 'query': '%22Led+Zeppelin%22', 'tweet_volume': 10773}, {'name': 'Crenshaw Mall', 'url': 'http://twitter.com/search?q=%22Crenshaw+Mall%22', 'promoted_content': None, 'query': '%22Crenshaw+Mall%22', 'tweet_volume': None}, {'name': 'Ducey', 'url': 'http://twitter.com/search?q=Ducey', 'promoted_content': None, 'query': 'Ducey', 'tweet_volume': None}, {'name': '#BlackInkCrew', 'url': 'http://twitter.com/search?q=%23BlackInkCrew', 'promoted_content': None, 'query': '%23BlackInkCrew', 'tweet_volume': None}, {'name': '#HOBICULT', 'url': 'http://twitter.com/search?q=%23HOBICULT', 'promoted_content': None, 'query': '%23HOBICULT', 'tweet_volume': 21846}, {'name': '#SistasOnBET', 'url': 'http://twitter.com/search?q=%23SistasOnBET', 'promoted_content': None, 'query': '%23SistasOnBET', 'tweet_volume': None}, {'name': '#TrumpsTheKingOf', 'url': 'http://twitter.com/search?q=%23TrumpsTheKingOf', 'promoted_content': None, 'query': '%23TrumpsTheKingOf', 'tweet_volume': 11555}, {'name': '#Riverdale', 'url': 'http://twitter.com/search?q=%23Riverdale', 'promoted_content': None, 'query': '%23Riverdale', 'tweet_volume': 18429}, {'name': '#my600lblife', 'url': 'http://twitter.com/search?q=%23my600lblife', 'promoted_content': None, 'query': '%23my600lblife', 'tweet_volume': None}, {'name': '#Jeopardy', 'url': 'http://twitter.com/search?q=%23Jeopardy', 'promoted_content': None, 'query': '%23Jeopardy', 'tweet_volume': None}, {'name': '#AssassinsCreedValhalla', 'url': 'http://twitter.com/search?q=%23AssassinsCreedValhalla', 'promoted_content': None, 'query': '%23AssassinsCreedValhalla', 'tweet_volume': 1595 ...

# %%
for trend in world_trends[0]['trends']:
    print(trend['name'])
# Out:
# #SecondLookAt7
# #OurMusicianRoséDay
# #YansınSuriyeYıkılsınİdlib
# #KPOP_FUTURE_DINOday
# #AskTrent
# Qinni
# Top 4
# Equifax
# Şehitlerimize Allah'tan
# #MAP_OF_THE_SOUL_7
# #الاهلي_الوحده_الاماراتي
# #FGO超初心者の頃の思い出
# #الهلال_شاهر_خودرو
# #OTDirecto10F
# #QueenRadio
# #الاتحاد_ضمك
# #heryerekitapheryerdekitap
# #حب_ولا_فلوس
# #FelizLunes
# #IFABkararınıUygulaTFF
# #ตัวแม่มาแล้วxมิวกลัฟ
# #ThalapathyVIJAYselfie
# #بندر_بن_سلطان
# #LtColVindmanDay
# #HarryOnHits1
# #DelhiResults
# #Happy_DINO_Day
# #MersindeBüyükDolandırıcı
# #BüfeKonduAliKıdık
# #歌のゴールデンヒット
# #日向坂46生誕祭
# #TurkFutboluIcinUyanmaZamani
# #bununsonu
# #شكلي_اذا
# #UKPunDay
# #نايف_فهد_الحمادي
# #AllAboutLuvForShownu
# #BUMPOFCHICKEN
# #AlacakuşUçtu
# #10Feb
# #HappyChannieBearDay
# #ShameonDelhiPolice
# #GOT7KEEPSPINNINGinBKK
# #FuchiCaca
# #مشهور_بالمدينه
# #IStandWithGayle
# #YALOVAdaHırsızlık
# #SupremeSid
# #onceselcaday
# #JO1ワイモバ学割

# %%
for trend in us_trends[0]['trends']:
    print(trend['name'])
# Out:
# Beyoncé
# #TheMaskedSinger
# #AEWDynamite
# #Survivor
# #TheChallenge35
# #WWENXT
# Nicki
# Flynn
# Ben Shapiro
# Harrison Ford
# Mauricio
# Kendall Jenner
# Linkin Park
# Parscale
# Telvin Smith
# Led Zeppelin
# Crenshaw Mall
# Ducey
# #BlackInkCrew
# #HOBICULT
# #SistasOnBET
# #TrumpsTheKingOf
# #Riverdale
# #my600lblife
# #Jeopardy
# #AssassinsCreedValhalla
# #TSRealAnime
# #StoryOfBarchie
# #EscapeLifeForAWhileBy
# #TSFakeAnime
# #PurposeDesign2020
# #OC20
# #QuarantineReboots
# #GhostNation

# %% [markdown]
# - The pattern for using the twitter module is simple and predictable:
#     - instantiate the Twitter class with an object chain corresponding to a base URL and then invoke methods on the object that correspond to URL contexts.
#     - For example, twitter_api.trends_place(id=WORLD_WOE_ID) initiates an HTTP call to GET
#      https://api.twitter.com/1.1/trends/available.json
#     - Example "url": "http://where.yahooapis.com/v1/place/2458410",
#     - "woeid": 2458410
#    - https://api.twitter.com/1.1/trends/place.json?id=1.
#     - Note the URL mapping to the object chain that’s constructed with the twitter package to make the request and how query string parameters are passed in as keyword arguments.
#     - To use the twitter package for arbitrary API requests, you generally construct the request in that kind of straightforward manner.
#     - *** add more explanation **

# %% [markdown]
# **Example 1-3. Displaying API responses as pretty-printed JSON**

# %%
#Displaying API responses as pretty-printed JSON
#Please refer to the following link to understand the json.dumps feature more
#https://www.w3schools.com/python/python_json.asp
    
import json

print(json.dumps(world_trends, indent=1))
print()
print(json.dumps(us_trends, indent=1))
# Out:
# [
#  {
#   "trends": [
#    {
#     "name": "#LIVEDOJAO",
#     "url": "http://twitter.com/search?q=%23LIVEDOJAO",
#     "promoted_content": null,
#     "query": "%23LIVEDOJAO",
#     "tweet_volume": 385291
#    },
#    {
#     "name": "#\u0641\u062d\u0635_\u0643\u0648\u0631\u0648\u0646\u0627",
#     "url": "http://twitter.com/search?q=%23%D9%81%D8%AD%D8%B5_%D9%83%D9%88%D8%B1%D9%88%D9%86%D8%A7",
#     "promoted_content": null,
#     "query": "%23%D9%81%D8%AD%D8%B5_%D9%83%D9%88%D8%B1%D9%88%D9%86%D8%A7",
#     "tweet_volume": 19057
#    },
#    {
#     "name": "Beyonc\u00e9",
#     "url": "http://twitter.com/search?q=Beyonc%C3%A9",
#     "promoted_content": null,
#     "query": "Beyonc%C3%A9",
#     "tweet_volume": 872767
#    },
#    {
#     "name": "#AEWDynamite",
#     "url": "http://twitter.com/search?q=%23AEWDynamite",
#     "promoted_content": null,
#     "query": "%23AEWDynamite",
#     "tweet_volume": 15114
#    },
#    {
#     "name": "#DireitaQuerImpeachment",
#     "url": "http://twitter.com/search?q=%23DireitaQuerImpeachment",
#     "promoted_content": null,
#     "query": "%23DireitaQuerImpeachment",
#     "tweet_volume": 33792
#    },
#    {
#     "name": "#LiveSomdoReino",
#     "url": "http://twitter.com/search?q=%23LiveSomdoReino",
#     "promoted_content": null,
#     "query": "%23LiveSomdoReino",
#     "tweet_volume": 14613
#    },
#    {
#     "name": "Nicki",
#     "url": "http://twitter.com/search?q=Nicki",
#     "promoted_content": null,
#     "query": "Nicki",
#     "tweet_volume": 230734
#    },
#    {
#     "name": "Vanoli",
#     "url": "http://twitter.com/search?q=Vanoli",
#     "promoted_content": null,
#     "query": "Vanoli",
#     "tweet_volume": 12385
#    },
#    {
#     "name": "Ben Shapiro",
#     "url": "http://twitter.com/search?q=%22Ben+Shapiro%22",
#     "promoted_content": null,
#     "query": "%22Ben+Shapiro%22",
#     "tweet_volume": 32603
#    },
#    {
#     "name": "Amaia",
#     "url": "http://twitter.com/search?q=Amaia",
#     "promoted_content": null,
#     "query": "Amaia",
#     "tweet_volume": 24845
#    },
#    {
#     "name": "Paris 6",
#     "url": "http://twitter.com/search?q=%22Paris+6%22",
#     "promoted_content": null,
#     "query": "%22Paris+6%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "MIYAVI",
#     "url": "http://twitter.com/search?q=MIYAVI",
#     "promoted_content": null,
#     "query": "MIYAVI",
#     "tweet_volume": null
#    },
#    {
#     "name": "OU\u00c7A AUDIO DE DESCULPAS",
#     "url": "http://twitter.com/search?q=%22OU%C3%87A+AUDIO+DE+DESCULPAS%22",
#     "promoted_content": null,
#     "query": "%22OU%C3%87A+AUDIO+DE+DESCULPAS%22",
#     "tweet_volume": 41436
#    },
#    {
#     "name": "\u5e73\u6210\u6700\u5f8c\u306e\u65e5",
#     "url": "http://twitter.com/search?q=%E5%B9%B3%E6%88%90%E6%9C%80%E5%BE%8C%E3%81%AE%E6%97%A5",
#     "promoted_content": null,
#     "query": "%E5%B9%B3%E6%88%90%E6%9C%80%E5%BE%8C%E3%81%AE%E6%97%A5",
#     "tweet_volume": null
#    },
#    {
#     "name": "JOAQU\u00cdN EN RAZE",
#     "url": "http://twitter.com/search?q=%22JOAQU%C3%8DN+EN+RAZE%22",
#     "promoted_content": null,
#     "query": "%22JOAQU%C3%8DN+EN+RAZE%22",
#     "tweet_volume": 58219
#    },
#    {
#     "name": "General Flynn",
#     "url": "http://twitter.com/search?q=%22General+Flynn%22",
#     "promoted_content": null,
#     "query": "%22General+Flynn%22",
#     "tweet_volume": 132992
#    },
#    {
#     "name": "87 in Lagos",
#     "url": "http://twitter.com/search?q=%2287+in+Lagos%22",
#     "promoted_content": null,
#     "query": "%2287+in+Lagos%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "AGUANTE LALI CARETAS",
#     "url": "http://twitter.com/search?q=%22AGUANTE+LALI+CARETAS%22",
#     "promoted_content": null,
#     "query": "%22AGUANTE+LALI+CARETAS%22",
#     "tweet_volume": 15259
#    },
#    {
#     "name": "#TheMaskedSinger",
#     "url": "http://twitter.com/search?q=%23TheMaskedSinger",
#     "promoted_content": null,
#     "query": "%23TheMaskedSinger",
#     "tweet_volume": 12959
#    },
#    {
#     "name": "#Survivor40",
#     "url": "http://twitter.com/search?q=%23Survivor40",
#     "promoted_content": null,
#     "query": "%23Survivor40",
#     "tweet_volume": null
#    },
#    {
#     "name": "#savageremix",
#     "url": "http://twitter.com/search?q=%23savageremix",
#     "promoted_content": null,
#     "query": "%23savageremix",
#     "tweet_volume": 125134
#    },
#    {
#     "name": "#WWENXT",
#     "url": "http://twitter.com/search?q=%23WWENXT",
#     "promoted_content": null,
#     "query": "%23WWENXT",
#     "tweet_volume": 10230
#    },
#    {
#     "name": "#\u0661_\u0645\u0627\u064a\u0648",
#     "url": "http://twitter.com/search?q=%23%D9%A1_%D9%85%D8%A7%D9%8A%D9%88",
#     "promoted_content": null,
#     "query": "%23%D9%A1_%D9%85%D8%A7%D9%8A%D9%88",
#     "tweet_volume": null
#    },
#    {
#     "name": "#hobicult",
#     "url": "http://twitter.com/search?q=%23hobicult",
#     "promoted_content": null,
#     "query": "%23hobicult",
#     "tweet_volume": 21048
#    },
#    {
#     "name": "#LiveMeB",
#     "url": "http://twitter.com/search?q=%23LiveMeB",
#     "promoted_content": null,
#     "query": "%23LiveMeB",
#     "tweet_volume": null
#    },
#    {
#     "name": "#BlackInkCrew",
#     "url": "http://twitter.com/search?q=%23BlackInkCrew",
#     "promoted_content": null,
#     "query": "%23BlackInkCrew",
#     "tweet_volume": null
#    },
#    {
#     "name": "#SM_\uc774\ud0dc\uc6a9_\uc9c0\ucf1c",
#     "url": "http://twitter.com/search?q=%23SM_%EC%9D%B4%ED%83%9C%EC%9A%A9_%EC%A7%80%EC%BC%9C",
#     "promoted_content": null,
#     "query": "%23SM_%EC%9D%B4%ED%83%9C%EC%9A%A9_%EC%A7%80%EC%BC%9C",
#     "tweet_volume": 525145
#    },
#    {
#     "name": "#\u0627\u0644\u0645\u0633\u062d_\u0627\u0644\u0645\u062c\u062a\u0645\u0639\u064a",
#     "url": "http://twitter.com/search?q=%23%D8%A7%D9%84%D9%85%D8%B3%D8%AD_%D8%A7%D9%84%D9%85%D8%AC%D8%AA%D9%85%D8%B9%D9%8A",
#     "promoted_content": null,
#     "query": "%23%D8%A7%D9%84%D9%85%D8%B3%D8%AD_%D8%A7%D9%84%D9%85%D8%AC%D8%AA%D9%85%D8%B9%D9%8A",
#     "tweet_volume": null
#    },
#    {
#     "name": "#TrumpsTheKingOf",
#     "url": "http://twitter.com/search?q=%23TrumpsTheKingOf",
#     "promoted_content": null,
#     "query": "%23TrumpsTheKingOf",
#     "tweet_volume": 11228
#    },
#    {
#     "name": "#AlbertoLiberaVioladores",
#     "url": "http://twitter.com/search?q=%23AlbertoLiberaVioladores",
#     "promoted_content": null,
#     "query": "%23AlbertoLiberaVioladores",
#     "tweet_volume": 21512
#    },
#    {
#     "name": "#\u30c4\u30a4\u30c3\u30bf\u30fc\u4e0d\u5177\u5408\u3060\u304b\u3089\u4f55\u8a00\u3063\u3066\u3082\u5927\u4e08\u592b",
#     "url": "http://twitter.com/search?q=%23%E3%83%84%E3%82%A4%E3%83%83%E3%82%BF%E3%83%BC%E4%B8%8D%E5%85%B7%E5%90%88%E3%81%A0%E3%81%8B%E3%82%89%E4%BD%95%E8%A8%80%E3%81%A3%E3%81%A6%E3%82%82%E5%A4%A7%E4%B8%88%E5%A4%AB",
#     "promoted_content": null,
#     "query": "%23%E3%83%84%E3%82%A4%E3%83%83%E3%82%BF%E3%83%BC%E4%B8%8D%E5%85%B7%E5%90%88%E3%81%A0%E3%81%8B%E3%82%89%E4%BD%95%E8%A8%80%E3%81%A3%E3%81%A6%E3%82%82%E5%A4%A7%E4%B8%88%E5%A4%AB",
#     "tweet_volume": 11058
#    },
#    {
#     "name": "#livebondedastronda",
#     "url": "http://twitter.com/search?q=%23livebondedastronda",
#     "promoted_content": null,
#     "query": "%23livebondedastronda",
#     "tweet_volume": null
#    },
#    {
#     "name": "#OtraVezMienten",
#     "url": "http://twitter.com/search?q=%23OtraVezMienten",
#     "promoted_content": null,
#     "query": "%23OtraVezMienten",
#     "tweet_volume": null
#    },
#    {
#     "name": "#AssassinsCreedValhalla",
#     "url": "http://twitter.com/search?q=%23AssassinsCreedValhalla",
#     "promoted_content": null,
#     "query": "%23AssassinsCreedValhalla",
#     "tweet_volume": 15853
#    },
#    {
#     "name": "#VenezuelaVictoriaDeLaPaz",
#     "url": "http://twitter.com/search?q=%23VenezuelaVictoriaDeLaPaz",
#     "promoted_content": null,
#     "query": "%23VenezuelaVictoriaDeLaPaz",
#     "tweet_volume": null
#    },
#    {
#     "name": "#preguntaleamhoni",
#     "url": "http://twitter.com/search?q=%23preguntaleamhoni",
#     "promoted_content": null,
#     "query": "%23preguntaleamhoni",
#     "tweet_volume": null
#    },
#    {
#     "name": "#\u0645\u062d\u0645\u062f_\u0633\u0639\u062f_\u0627\u0644\u0642\u062d\u0637\u0627\u0646\u064a_\u0641\u064a_\u0630\u0645\u0647_\u0627\u0644\u0644\u0647",
#     "url": "http://twitter.com/search?q=%23%D9%85%D8%AD%D9%85%D8%AF_%D8%B3%D8%B9%D8%AF_%D8%A7%D9%84%D9%82%D8%AD%D8%B7%D8%A7%D9%86%D9%8A_%D9%81%D9%8A_%D8%B0%D9%85%D9%87_%D8%A7%D9%84%D9%84%D9%87",
#     "promoted_content": null,
#     "query": "%23%D9%85%D8%AD%D9%85%D8%AF_%D8%B3%D8%B9%D8%AF_%D8%A7%D9%84%D9%82%D8%AD%D8%B7%D8%A7%D9%86%D9%8A_%D9%81%D9%8A_%D8%B0%D9%85%D9%87_%D8%A7%D9%84%D9%84%D9%87",
#     "tweet_volume": null
#    },
#    {
#     "name": "#SeAcab\u00f3LaChela",
#     "url": "http://twitter.com/search?q=%23SeAcab%C3%B3LaChela",
#     "promoted_content": null,
#     "query": "%23SeAcab%C3%B3LaChela",
#     "tweet_volume": 14243
#    },
#    {
#     "name": "#MaltepeCezaevindeNeleroluyor",
#     "url": "http://twitter.com/search?q=%23MaltepeCezaevindeNeleroluyor",
#     "promoted_content": null,
#     "query": "%23MaltepeCezaevindeNeleroluyor",
#     "tweet_volume": 50467
#    },
#    {
#     "name": "#at\u0131l\u0131m\u00f6\u011frenciyezul\u00fcmetme",
#     "url": "http://twitter.com/search?q=%23at%C4%B1l%C4%B1m%C3%B6%C4%9Frenciyezul%C3%BCmetme",
#     "promoted_content": null,
#     "query": "%23at%C4%B1l%C4%B1m%C3%B6%C4%9Frenciyezul%C3%BCmetme",
#     "tweet_volume": 11272
#    },
#    {
#     "name": "#RezilsinCHP",
#     "url": "http://twitter.com/search?q=%23RezilsinCHP",
#     "promoted_content": null,
#     "query": "%23RezilsinCHP",
#     "tweet_volume": 87497
#    },
#    {
#     "name": "#\u0639\u0642\u062f_\u0627\u064a\u062c\u0627\u06316",
#     "url": "http://twitter.com/search?q=%23%D8%B9%D9%82%D8%AF_%D8%A7%D9%8A%D8%AC%D8%A7%D8%B16",
#     "promoted_content": null,
#     "query": "%23%D8%B9%D9%82%D8%AF_%D8%A7%D9%8A%D8%AC%D8%A7%D8%B16",
#     "tweet_volume": 22724
#    },
#    {
#     "name": "#LaSalvaraSuMadre",
#     "url": "http://twitter.com/search?q=%23LaSalvaraSuMadre",
#     "promoted_content": null,
#     "query": "%23LaSalvaraSuMadre",
#     "tweet_volume": null
#    },
#    {
#     "name": "#QueremosQueCritticoRegrese",
#     "url": "http://twitter.com/search?q=%23QueremosQueCritticoRegrese",
#     "promoted_content": null,
#     "query": "%23QueremosQueCritticoRegrese",
#     "tweet_volume": 13440
#    },
#    {
#     "name": "#ReduzcamosLaCurva",
#     "url": "http://twitter.com/search?q=%23ReduzcamosLaCurva",
#     "promoted_content": null,
#     "query": "%23ReduzcamosLaCurva",
#     "tweet_volume": 20551
#    },
#    {
#     "name": "#NoSeanFrescos",
#     "url": "http://twitter.com/search?q=%23NoSeanFrescos",
#     "promoted_content": null,
#     "query": "%23NoSeanFrescos",
#     "tweet_volume": null
#    },
#    {
#     "name": "#MediosMacristasMentirosos",
#     "url": "http://twitter.com/search?q=%23MediosMacristasMentirosos",
#     "promoted_content": null,
#     "query": "%23MediosMacristasMentirosos",
#     "tweet_volume": 15435
#    },
#    {
#     "name": "#tribodaperiferia",
#     "url": "http://twitter.com/search?q=%23tribodaperiferia",
#     "promoted_content": null,
#     "query": "%23tribodaperiferia",
#     "tweet_volume": null
#    },
#    {
#     "name": "#\u0e40\u0e1e\u0e25\u0e07\u0e43\u0e2b\u0e21\u0e48\u0e40\u0e2e\u0e35\u0e22\u0e40\u0e1e\u0e23\u0e32\u0e30\u0e21\u0e32\u0e01",
#     "url": "http://twitter.com/search?q=%23%E0%B9%80%E0%B8%9E%E0%B8%A5%E0%B8%87%E0%B9%83%E0%B8%AB%E0%B8%A1%E0%B9%88%E0%B9%80%E0%B8%AE%E0%B8%B5%E0%B8%A2%E0%B9%80%E0%B8%9E%E0%B8%A3%E0%B8%B2%E0%B8%B0%E0%B8%A1%E0%B8%B2%E0%B8%81",
#     "promoted_content": null,
#     "query": "%23%E0%B9%80%E0%B8%9E%E0%B8%A5%E0%B8%87%E0%B9%83%E0%B8%AB%E0%B8%A1%E0%B9%88%E0%B9%80%E0%B8%AE%E0%B8%B5%E0%B8%A2%E0%B9%80%E0%B8%9E%E0%B8%A3%E0%B8%B2%E0%B8%B0%E0%B8%A1%E0%B8%B2%E0%B8%81",
#     "tweet_volume": null
#    },
#    {
#     "name": "#\u063a\u0631\u062f_\u0647\u0646\u0627_\u0628\u0634\u064a_\u062d\u0644\u0648",
#     "url": "http://twitter.com/search?q=%23%D8%BA%D8%B1%D8%AF_%D9%87%D9%86%D8%A7_%D8%A8%D8%B4%D9%8A_%D8%AD%D9%84%D9%88",
#     "promoted_content": null,
#     "query": "%23%D8%BA%D8%B1%D8%AF_%D9%87%D9%86%D8%A7_%D8%A8%D8%B4%D9%8A_%D8%AD%D9%84%D9%88",
#     "tweet_volume": null
#    }
#   ],
#   "as_of": "2020-04-30T01:12:16Z",
#   "created_at": "2020-04-30T01:02:57Z",
#   "locations": [
#    {
#     "name": "Worldwide",
#     "woeid": 1
#    }
#   ]
#  }
# ]
#
# [
#  {
#   "trends": [
#    {
#     "name": "Beyonc\u00e9",
#     "url": "http://twitter.com/search?q=Beyonc%C3%A9",
#     "promoted_content": null,
#     "query": "Beyonc%C3%A9",
#     "tweet_volume": 878117
#    },
#    {
#     "name": "#TheMaskedSinger",
#     "url": "http://twitter.com/search?q=%23TheMaskedSinger",
#     "promoted_content": null,
#     "query": "%23TheMaskedSinger",
#     "tweet_volume": 13614
#    },
#    {
#     "name": "#AEWDynamite",
#     "url": "http://twitter.com/search?q=%23AEWDynamite",
#     "promoted_content": null,
#     "query": "%23AEWDynamite",
#     "tweet_volume": 16383
#    },
#    {
#     "name": "#Survivor",
#     "url": "http://twitter.com/search?q=%23Survivor",
#     "promoted_content": null,
#     "query": "%23Survivor",
#     "tweet_volume": 15416
#    },
#    {
#     "name": "#TheChallenge35",
#     "url": "http://twitter.com/search?q=%23TheChallenge35",
#     "promoted_content": null,
#     "query": "%23TheChallenge35",
#     "tweet_volume": null
#    },
#    {
#     "name": "#WWENXT",
#     "url": "http://twitter.com/search?q=%23WWENXT",
#     "promoted_content": null,
#     "query": "%23WWENXT",
#     "tweet_volume": 11279
#    },
#    {
#     "name": "Nicki",
#     "url": "http://twitter.com/search?q=Nicki",
#     "promoted_content": null,
#     "query": "Nicki",
#     "tweet_volume": 232232
#    },
#    {
#     "name": "Flynn",
#     "url": "http://twitter.com/search?q=Flynn",
#     "promoted_content": null,
#     "query": "Flynn",
#     "tweet_volume": 473770
#    },
#    {
#     "name": "Ben Shapiro",
#     "url": "http://twitter.com/search?q=%22Ben+Shapiro%22",
#     "promoted_content": null,
#     "query": "%22Ben+Shapiro%22",
#     "tweet_volume": 33018
#    },
#    {
#     "name": "Harrison Ford",
#     "url": "http://twitter.com/search?q=%22Harrison+Ford%22",
#     "promoted_content": null,
#     "query": "%22Harrison+Ford%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Mauricio",
#     "url": "http://twitter.com/search?q=Mauricio",
#     "promoted_content": null,
#     "query": "Mauricio",
#     "tweet_volume": 47878
#    },
#    {
#     "name": "Kendall Jenner",
#     "url": "http://twitter.com/search?q=%22Kendall+Jenner%22",
#     "promoted_content": null,
#     "query": "%22Kendall+Jenner%22",
#     "tweet_volume": 18131
#    },
#    {
#     "name": "Linkin Park",
#     "url": "http://twitter.com/search?q=%22Linkin+Park%22",
#     "promoted_content": null,
#     "query": "%22Linkin+Park%22",
#     "tweet_volume": 23604
#    },
#    {
#     "name": "Parscale",
#     "url": "http://twitter.com/search?q=Parscale",
#     "promoted_content": null,
#     "query": "Parscale",
#     "tweet_volume": 27492
#    },
#    {
#     "name": "Telvin Smith",
#     "url": "http://twitter.com/search?q=%22Telvin+Smith%22",
#     "promoted_content": null,
#     "query": "%22Telvin+Smith%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Led Zeppelin",
#     "url": "http://twitter.com/search?q=%22Led+Zeppelin%22",
#     "promoted_content": null,
#     "query": "%22Led+Zeppelin%22",
#     "tweet_volume": 10773
#    },
#    {
#     "name": "Crenshaw Mall",
#     "url": "http://twitter.com/search?q=%22Crenshaw+Mall%22",
#     "promoted_content": null,
#     "query": "%22Crenshaw+Mall%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Ducey",
#     "url": "http://twitter.com/search?q=Ducey",
#     "promoted_content": null,
#     "query": "Ducey",
#     "tweet_volume": null
#    },
#    {
#     "name": "#BlackInkCrew",
#     "url": "http://twitter.com/search?q=%23BlackInkCrew",
#     "promoted_content": null,
#     "query": "%23BlackInkCrew",
#     "tweet_volume": null
#    },
#    {
#     "name": "#HOBICULT",
#     "url": "http://twitter.com/search?q=%23HOBICULT",
#     "promoted_content": null,
#     "query": "%23HOBICULT",
#     "tweet_volume": 21846
#    },
#    {
#     "name": "#SistasOnBET",
#     "url": "http://twitter.com/search?q=%23SistasOnBET",
#     "promoted_content": null,
#     "query": "%23SistasOnBET",
#     "tweet_volume": null
#    },
#    {
#     "name": "#TrumpsTheKingOf",
#     "url": "http://twitter.com/search?q=%23TrumpsTheKingOf",
#     "promoted_content": null,
#     "query": "%23TrumpsTheKingOf",
#     "tweet_volume": 11555
#    },
#    {
#     "name": "#Riverdale",
#     "url": "http://twitter.com/search?q=%23Riverdale",
#     "promoted_content": null,
#     "query": "%23Riverdale",
#     "tweet_volume": 18429
#    },
#    {
#     "name": "#my600lblife",
#     "url": "http://twitter.com/search?q=%23my600lblife",
#     "promoted_content": null,
#     "query": "%23my600lblife",
#     "tweet_volume": null
#    },
#    {
#     "name": "#Jeopardy",
#     "url": "http://twitter.com/search?q=%23Jeopardy",
#     "promoted_content": null,
#     "query": "%23Jeopardy",
#     "tweet_volume": null
#    },
#    {
#     "name": "#AssassinsCreedValhalla",
#     "url": "http://twitter.com/search?q=%23AssassinsCreedValhalla",
#     "promoted_content": null,
#     "query": "%23AssassinsCreedValhalla",
#     "tweet_volume": 15950
#    },
#    {
#     "name": "#TSRealAnime",
#     "url": "http://twitter.com/search?q=%23TSRealAnime",
#     "promoted_content": null,
#     "query": "%23TSRealAnime",
#     "tweet_volume": null
#    },
#    {
#     "name": "#StoryOfBarchie",
#     "url": "http://twitter.com/search?q=%23StoryOfBarchie",
#     "promoted_content": null,
#     "query": "%23StoryOfBarchie",
#     "tweet_volume": 12847
#    },
#    {
#     "name": "#EscapeLifeForAWhileBy",
#     "url": "http://twitter.com/search?q=%23EscapeLifeForAWhileBy",
#     "promoted_content": null,
#     "query": "%23EscapeLifeForAWhileBy",
#     "tweet_volume": null
#    },
#    {
#     "name": "#TSFakeAnime",
#     "url": "http://twitter.com/search?q=%23TSFakeAnime",
#     "promoted_content": null,
#     "query": "%23TSFakeAnime",
#     "tweet_volume": null
#    },
#    {
#     "name": "#PurposeDesign2020",
#     "url": "http://twitter.com/search?q=%23PurposeDesign2020",
#     "promoted_content": null,
#     "query": "%23PurposeDesign2020",
#     "tweet_volume": null
#    },
#    {
#     "name": "#OC20",
#     "url": "http://twitter.com/search?q=%23OC20",
#     "promoted_content": null,
#     "query": "%23OC20",
#     "tweet_volume": null
#    },
#    {
#     "name": "#QuarantineReboots",
#     "url": "http://twitter.com/search?q=%23QuarantineReboots",
#     "promoted_content": null,
#     "query": "%23QuarantineReboots",
#     "tweet_volume": null
#    },
#    {
#     "name": "#GhostNation",
#     "url": "http://twitter.com/search?q=%23GhostNation",
#     "promoted_content": null,
#     "query": "%23GhostNation",
#     "tweet_volume": null
#    }
#   ],
#   "as_of": "2020-04-30T01:12:16Z",
#   "created_at": "2020-04-30T01:07:55Z",
#   "locations": [
#    {
#     "name": "United States",
#     "woeid": 23424977
#    }
#   ]
#  }
# ]

# %% [markdown]
# **Example 1-4**
# - Demonstrates how to use a Python list comprehension to parse out the names of the trending topics from the results that were previously queried, cast those lists to sets, and compute the setwise intersection to reveal the common items between them.
# - Please refere to the following link to understand list comprehension more
# - https://docs.python.org/2/tutorial/datastructures.html#list-comprehensions

# %%
world_trends_set = set([trend['name'] 
                        for trend in world_trends[0]['trends']])

us_trends_set = set([trend['name'] 
                     for trend in us_trends[0]['trends']]) 

common_trends = world_trends_set.intersection(us_trends_set)

print(common_trends)
# Out:
# {'Ben Shapiro', '#TrumpsTheKingOf', 'Beyoncé', '#TheMaskedSinger', '#BlackInkCrew', '#AEWDynamite', '#WWENXT', '#AssassinsCreedValhalla', 'Nicki'}

# %% [markdown]
# **Example 1-5 Searching for Tweets**
# - One of the common items between the sets of trending topics turns out to be the hashtag #MentionSomeoneImportantForYou, so let’s use it as the basis of a search query to fetch some tweets for further analysis.
# - In this example we are going to illustrate how to exercise the GET search/tweets resource for a particular query of interest, including the ability to use a special field that’s included in the metadata for the search results to easily make additional requests for more search results.

# %% [markdown]
# - The use of *args and **kwargs as  parameters to a function is a Python idiom for expressing arbitrary arguments and keyword arguments, respectively

# %% [markdown]
# *****NEED FIXING TO USE CURSOR INSTEAD OF THE METHOD BELOW***
# **Code will be updated tomorrow**

# %% [markdown]
# **Anatomy of a Tweet**
# - https://learning.oreilly.com/library/view/mining-the-social/9781491973547/ch01.html

# %%
import json

# Set this variable to a trending topic, 
# or anything else for that matter. The example query below
# was a trending topic when this content was being developed
# and is used throughout the remainder of this chapter.

q = '#MothersDay' 

count = 100

# Import unquote to prevent url encoding errors in next_results
from urllib.parse import unquote

# See https://dev.twitter.com/rest/reference/get/search/tweets

search_results = []
for tweet in tweepy.Cursor (twitter_api.search, q = q, lang = "en").items(100): 
    search_results.append(tweet)

# %%
for i in range(10):
    print()
    print(statuses[i]['text'])
    print('Favorites: ', statuses[i]['favorite_count'])
    print('Retweets: ', statuses[i]['retweet_count'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-14-cb56daee3575> in <module>
#       1 for i in range(10):
#       2     print()
# ----> 3     print(statuses[i]['text'])
#       4     print('Favorites: ', statuses[i]['favorite_count'])
#       5     print('Retweets: ', statuses[i]['retweet_count'])
#
# TypeError: 'Status' object is not subscriptable

# %% [markdown]
# ## Extracting text, screen names, and hashtags from tweets

# %%
status_texts = [ status['text'] 
                 for status in statuses ]

screen_names = [ user_mention['screen_name'] 
                 for status in statuses
                     for user_mention in status['entities']['user_mentions'] ]

hashtags = [ hashtag['text'] 
             for status in statuses
                 for hashtag in status['entities']['hashtags'] ]

# Compute a collection of all words from all tweets
words = [ w 
          for t in status_texts 
              for w in t.split() ]

# Explore the first 5 items for each...

print(json.dumps(status_texts[0:5], indent=1))
print(json.dumps(screen_names[0:5], indent=1) )
print(json.dumps(hashtags[0:5], indent=1))
print(json.dumps(words[0:5], indent=1))

# %% [markdown]
# ## Creating a basic frequency distribution from the words in tweets

# %%
from collections import Counter

for item in [words, screen_names, hashtags]:
    c = Counter(item)
    print(c.most_common()[:10]) # top 10
    print()

# %% [markdown]
# ## Using prettytable to display tuples in a nice tabular format

# %%
from prettytable import PrettyTable

for label, data in (('Word', words), 
                    ('Screen Name', screen_names), 
                    ('Hashtag', hashtags)):
    pt = PrettyTable(field_names=[label, 'Count']) 
    c = Counter(data)
    [ pt.add_row(kv) for kv in c.most_common()[:10] ]
    pt.align[label], pt.align['Count'] = 'l', 'r' # Set column alignment
    print(pt)

# %% [markdown]
# ## Calculating lexical diversity for tweets

# %%
# A function for computing lexical diversity
def lexical_diversity(tokens):
    return len(set(tokens))/len(tokens) 

# A function for computing the average number of words per tweet
def average_words(statuses):
    total_words = sum([ len(s.split()) for s in statuses ]) 
    return total_words/len(statuses)

print(lexical_diversity(words))
print(lexical_diversity(screen_names))
print(lexical_diversity(hashtags))
print(average_words(status_texts))

# %% [markdown]
# ## Finding the most popular retweets

# %%
retweets = [
            # Store out a tuple of these three values ...
            (status['retweet_count'], 
             status['retweeted_status']['user']['screen_name'],
             status['retweeted_status']['id'],
             status['text']) 
            
            # ... for each status ...
            for status in statuses 
            
            # ... so long as the status meets this condition.
                if 'retweeted_status' in status.keys()
           ]

# Slice off the first 5 from the sorted results and display each item in the tuple

pt = PrettyTable(field_names=['Count', 'Screen Name', 'Tweet ID', 'Text'])
[ pt.add_row(row) for row in sorted(retweets, reverse=True)[:5] ]
pt.max_width['Text'] = 50
pt.align= 'l'
print(pt)

# %% [markdown]
# ## Looking up users who have retweeted a status

# %%
# Get the original tweet id for a tweet from its retweeted_status node 
# and insert it here

_retweets = twitter_api.statuses.retweets(id=862359093398261760)
print([r['user']['screen_name'] for r in _retweets])

# %% [markdown]
# ## Plotting frequencies of words

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
word_counts = sorted(Counter(words).values(), reverse=True)

plt.loglog(word_counts)
plt.ylabel("Freq")
plt.xlabel("Word Rank")

# %% [markdown]
# ## Generating histograms of words, screen names, and hashtags

# %%
for label, data in (('Words', words), 
                    ('Screen Names', screen_names), 
                    ('Hashtags', hashtags)):

    # Build a frequency map for each set of data
    # and plot the values
    c = Counter(data)
    plt.hist(list(c.values()))
    
    # Add a title and y-label ...
    plt.title(label)
    plt.ylabel("Number of items in bin")
    plt.xlabel("Bins (number of times an item appeared)")
    
    # ... and display as a new figure
    plt.figure()

# %% [markdown]
# ## Generating a histogram of retweet counts

# %%
# Using underscores while unpacking values in
# a tuple is idiomatic for discarding them

counts = [count for count, _, _, _ in retweets]

plt.hist(counts)
plt.title('Retweets')
plt.xlabel('Bins (number of times retweeted)')
plt.ylabel('Number of tweets in bin')

# %% [markdown]
# ## Sentiment Analysis

# %%
# pip install nltk
import nltk
nltk.download('vader_lexicon')

import numpy as np
from nltk.sentiment.vader import SentimentIntensityAnalyzer

# %%
twitter_stream = twitter.TwitterStream(auth=auth)
iterator = twitter_stream.statuses.sample()

# %%
tweets = []
for tweet in iterator:
    try:
        if tweet['lang'] == 'en':
            tweets.append(tweet)
    except:
        pass
    if len(tweets) == 100:
        break

# %%
analyzer = SentimentIntensityAnalyzer()

# %%
analyzer.polarity_scores('Hello')

# %%
analyzer.polarity_scores('I really enjoy this video series.')

# %%
analyzer.polarity_scores('I REALLY enjoy this video series.')

# %%
analyzer.polarity_scores('I REALLY enjoy this video series!!!')

# %%
analyzer.polarity_scores('I REALLY did not enjoy this video series!!!')

# %%
scores = np.zeros(len(tweets))

for i, t in enumerate(tweets):
    # Extract the text portion of the tweet
    text = t['text']
    
    # Measure the polarity of the tweet
    polarity = analyzer.polarity_scores(text)
    
    # Store the normalized, weighted composite score
    scores[i] = polarity['compound']

# %%
most_positive = np.argmax(scores)
most_negative = np.argmin(scores)

# %%
print('{0:6.3f} : "{1}"'.format(scores[most_positive], tweets[most_positive]['text']))

# %%
print('{0:6.3f} : "{1}"'.format(scores[most_negative], tweets[most_negative]['text']))
