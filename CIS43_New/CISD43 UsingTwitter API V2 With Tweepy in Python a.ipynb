# %% [markdown]
# - Reference: (Quoted from the following references-Modification and More explanation has been added)
#     - https://python.plainenglish.io/twitter-api-v2-programming-with-python-and-tweepy-f6487cd4bad9
#         - (Exclude the part for flask- you can learn that in advanced python class)
#     - https://dev.to/twitterdev/a-comprehensive-guide-for-using-the-twitter-api-v2-using-tweepy-in-python-15d9
#     - https://docs.tweepy.org/en/latest/examples.html
#     - Very useful one:
#     - https://github.com/twitterdev/getting-started-with-the-twitter-api-v2-for-academic-research

# %% [markdown]
# - In this example we ar going to discuss the following
# - Introduction
# - Tweepy Documentation
# - Understanding Twitter API access levels
# - Creating your app and getting keys and tokens
# - Installing Tweepy
# - Searching for Tweets from last 7 days
# - Searching for Geo-tagged Tweets from full-archive search
# - Getting more than 100 Tweets
# - Writing Tweets to a text file
# - Searching for Tweets using the full-archive search
# - Getting Tweet counts
# - Getting a user's timeline and mentions
# - Getting a user's followers and following
# - Get users that like a Tweet
# - Get retweeters of a Tweet
# - Looking up a Tweet using Tweet ID
# - Creating a Tweet with text
# - Creating a poll
# - Retweeting a Tweet
# - Reply to a Tweet

# %% [markdown]
# - What is Bearer token and How it works?
# - https://www.devopsschool.com/blog/what-is-bearer-token-and-how-it-works/

# %% [markdown]
# - With V2, the main difference is the authentication — instead of creating the API, you create the client with this code:
# - client = tweepy.Client(bearer_token='enter-token',
#                        consumer_key='enter-consumer-key',
#                        consumer_secret='enter-consumer-secret',
#                        access_token='enter-access-token',
#                        access_token_secret='enter-secret')

# %% [markdown]
# - Prerequisite
#   - In order to work with the Twitter API, you need to have a developer account and your API keys and tokens to connect to the API.

# %% [markdown]
# **How to obtain these keys and tokens**
# - https://developer.twitter.com/en/docs/twitter-api/getting-started/getting-access-to-the-twitter-api

# %% [markdown]
# - In order to work with Tweepy, make sure you have Python installed on your machine. Then, in the terminal run:
#     - pip3 install tweepy
# - Note: If you already have Tweepy installed, you can upgrade it to the latest version i.e. 4.0 by running:
#     - pip3 install tweepy --upgrade

# %% [markdown]
# - For all the examples in this section, you will first need to import the tweepy library, then you will need to initialize the client by passing it your bearer token. Once you have the client initialized, you will be ready to start using the various functions in this library.
#     - import tweepy
#     - client = tweepy.Client(bearer_token='REPLACE_ME')
# - It is recommended to save your tokens and access keys in a file outside your jupyter notebook

# %% [markdown]
# **Tweepy documentation**
# - **https://docs.tweepy.org/en/latest/**
# - **https://developer.twitter.com/en/docs/twitter-api**
# - **Examples from the documentation: https://docs.tweepy.org/en/latest/examples.html**

# %% [markdown]
# **Understanding Twitter API access levels**
# - https://developer.twitter.com/en/docs/twitter-api/getting-started/about-twitter-api
#     - Essential access is available for anybody who signs for it and you do not need to wait for a use case review.
#     - You sign up and you get certain functionality on the twitter api v2. You will only get access from tweets from the last seven days.
#     - You can get up to 500 thousand tweets per month. That basically means that when you retrieve tweets you can get up to 500 thousand tweets per month as part of this essential access.
#     - If you want to get more you can apply to use a case review and according to your use case, you can get access to the elevated package. You can get up to two million tweets per month.
#     - If you are a research student you can apply for a use case review for academic research and once you are approved, you get up to 10 million tweets per month. You also get access to the full archive search since 2006.

# %% [markdown]
# **Creating your app and getting keys and tokens**
# - You need to create an app, it will be as a placeholder for you keys and tokens.
# - You can authenticate your self bearer token or api keys
# - Check the videos posted in the useful links related to that.
# - Go to app settings
#     - Set the permission to use OAuth 1.0a
#     - Set permission to read and write
#
# ![permissions.png](attachment:permissions.png)
#
# -
#
#     -

# %% [markdown]
# - How to find and regenerate your API Key and Secret after App creation
# - If you've already created an App and need to find or regenerate your API Key and Secret, please follow these steps:
#
# - Navigate to the developer portal
# - https://developer.twitter.com/en/portal/projects-and-apps
# - Expand the 'Projects and Apps' dropdown in the sidenav
# - Open the App which is associated with the API Key and Secret that you would like to find or regenerate
# - Navigate to the Keys and tokens tab
# - From there, you will find all of the credentials associated with your App.
