# %% [markdown]
# **Mining Twitter**
# - Reference Chapter 1 of Mining the Social Web, 3rd Edition
# - Safari books online library
#
# **Note**
# **Some of the code snippets in the book got depreciated
# Fixes has been done in this example**
#
# - Twitter implements OAuth 1.0A as its standard authentication mechanism, and in order to use it to make requests to Twitter's API, you'll need to go to https://developer.twitter.com/en/apps and create a sample application.
# - It is possible that Twitter no longer supports sandboxed applications and you may need to submit a request for permission to develop an app on Twitter.
# - There are four primary identifiers you'll need to note for an OAuth 1.0A workflow: consumer key, consumer secret, access token, and access token secret.
# - Note that you will need an ordinary Twitter account in order to login, create an app, and get these credentials.
#
# <img src="images/Twitter-AppCredentials.png" width="600px">
#
# - Please do not use the access token provided below those are mine.
# - You need to use yours.

# %% [markdown]
# - pip install tweepy

# %% [markdown]
# ## Authorizing an application to access Twitter account data

# %%
#import libraries that you need
import tweepy
from tweepy import OAuthHandler, Stream
from credentials import *
# Go to https://developer.twitter.com/en/apps to create an app and get values
# for these credentials, which you'll need to provide in place of these
# empty string values that are defined as placeholders.
# See https://developer.twitter.com/en/docs/basics/authentication/overview/oauth
# for more information on Twitter's OAuth implementation.



auth = tweepy.OAuthHandler(CONSUMER_KEY, CONSUMER_SECRET)
auth.set_access_token(ACCESS_TOKEN, ACCESS_SECRET)
 
twitter_api = tweepy.API(auth,  wait_on_rate_limit=True)

# Nothing to see by displaying twitter_api except that it's now a
# defined variable

print(twitter_api)
# Out:
# <tweepy.api.API object at 0x7ff368248760>

# %% [markdown]
# **Very import links**
# - http://docs.tweepy.org/en/v3.5.0/api.html#API.trends_place

# %% [markdown]
# **Example 1-2. Retrieving trends**

# %% [markdown]
# **Exploring Trending Topics**
# - We are going to Twitter for the topics that are currently trending worldwide, but keep in mind that the API can easily be parameterized to constrain the topics to more specific locales if you feel inclined to try out some of the possibilities.
# - The device for constraining queries is via Yahoo! GeoPlanet’s Where On Earth (WOE) ID system, which is an API unto itself that aims to provide a way to map a unique identifier to any named place on Earth (or theoretically, even in a virtual world).
# - We are going to collect a set of trends for both the entire world and just the United States.

# %%
# The Yahoo! Where On Earth ID for the entire world is 1.
# See https://developer.twitter.com/en/docs/trends/locations-with-trending-topics/api-reference/get-trends-available

WORLD_WOE_ID = 1
US_WOE_ID = 23424977

# Prefix ID with the underscore for query string parameterization.
# Without the underscore, the twitter package appends the ID value
# to the URL itself as a special case keyword argument.

world_trends = twitter_api.get_place_trends(id=WORLD_WOE_ID)
us_trends = twitter_api.get_place_trends(id=US_WOE_ID)

print(world_trends)
print("*******************")
print(us_trends)
# Out:
# [{'trends': [{'name': '#BamBamxโหนกระแส', 'url': 'http://twitter.com/search?q=%23BamBamx%E0%B9%82%E0%B8%AB%E0%B8%99%E0%B8%81%E0%B8%A3%E0%B8%B0%E0%B9%81%E0%B8%AA', 'promoted_content': None, 'query': '%23BamBamx%E0%B9%82%E0%B8%AB%E0%B8%99%E0%B8%81%E0%B8%A3%E0%B8%B0%E0%B9%81%E0%B8%AA', 'tweet_volume': 374871}, {'name': '#AmbedkarJayanti', 'url': 'http://twitter.com/search?q=%23AmbedkarJayanti', 'promoted_content': None, 'query': '%23AmbedkarJayanti', 'tweet_volume': 133782}, {'name': 'Ret e L7', 'url': 'http://twitter.com/search?q=%22Ret+e+L7%22', 'promoted_content': None, 'query': '%22Ret+e+L7%22', 'tweet_volume': 43453}, {'name': 'Freddy Rincón', 'url': 'http://twitter.com/search?q=%22Freddy+Rinc%C3%B3n%22', 'promoted_content': None, 'query': '%22Freddy+Rinc%C3%B3n%22', 'tweet_volume': 64001}, {'name': 'Filipe Ret', 'url': 'http://twitter.com/search?q=%22Filipe+Ret%22', 'promoted_content': None, 'query': '%22Filipe+Ret%22', 'tweet_volume': 28765}, {'name': 'Rwanda', 'url': 'http://twitter.com/search?q=Rwanda', 'promoted_content': None, 'query': 'Rwanda', 'tweet_volume': 50105}, {'name': '#HalodocRamadan', 'url': 'http://twitter.com/search?q=%23HalodocRamadan', 'promoted_content': None, 'query': '%23HalodocRamadan', 'tweet_volume': None}, {'name': 'PA e Scooby', 'url': 'http://twitter.com/search?q=%22PA+e+Scooby%22', 'promoted_content': None, 'query': '%22PA+e+Scooby%22', 'tweet_volume': 27273}, {'name': '#Baisakhi', 'url': 'http://twitter.com/search?q=%23Baisakhi', 'promoted_content': None, 'query': '%23Baisakhi', 'tweet_volume': 10817}, {'name': 'L7nnon', 'url': 'http://twitter.com/search?q=L7nnon', 'promoted_content': None, 'query': 'L7nnon', 'tweet_volume': 18224}, {'name': '#インターネット老人音楽祭', 'url': 'http://twitter.com/search?q=%23%E3%82%A4%E3%83%B3%E3%82%BF%E3%83%BC%E3%83%8D%E3%83%83%E3%83%88%E8%80%81%E4%BA%BA%E9%9F%B3%E6%A5%BD%E7%A5%AD', 'promoted_content': None, 'query': '%23%E3%82%A4%E3%83%B3%E3%82%BF%E3%83%BC%E3%83%8D%E3%83%83%E3%83%88%E8%80%81%E4%BA%BA%E9%9F%B3%E6%A5%BD%E7%A5%AD', 'tweet_volume': None}, {'name': 'インターネットのヲタク', 'url': 'http://twitter.com/search?q=%E3%82%A4%E3%83%B3%E3%82%BF%E3%83%BC%E3%83%8D%E3%83%83%E3%83%88%E3%81%AE%E3%83%B2%E3%82%BF%E3%82%AF', 'promoted_content': None, 'query': '%E3%82%A4%E3%83%B3%E3%82%BF%E3%83%BC%E3%83%8D%E3%83%83%E3%83%88%E3%81%AE%E3%83%B2%E3%82%BF%E3%82%AF', 'tweet_volume': None}, {'name': 'じゅじゅステ', 'url': 'http://twitter.com/search?q=%E3%81%98%E3%82%85%E3%81%98%E3%82%85%E3%82%B9%E3%83%86', 'promoted_content': None, 'query': '%E3%81%98%E3%82%85%E3%81%98%E3%82%85%E3%82%B9%E3%83%86', 'tweet_volume': None}, {'name': '三浦涼介', 'url': 'http://twitter.com/search?q=%E4%B8%89%E6%B5%A6%E6%B6%BC%E4%BB%8B', 'promoted_content': None, 'query': '%E4%B8%89%E6%B5%A6%E6%B6%BC%E4%BB%8B', 'tweet_volume': 34737}, {'name': '磯丸水産', 'url': 'http://twitter.com/search?q=%E7%A3%AF%E4%B8%B8%E6%B0%B4%E7%94%A3', 'promoted_content': None, 'query': '%E7%A3%AF%E4%B8%B8%E6%B0%B4%E7%94%A3', 'tweet_volume': None}, {'name': 'Daily Quordle 80', 'url': 'http://twitter.com/search?q=%22Daily+Quordle+80%22', 'promoted_content': None, 'query': '%22Daily+Quordle+80%22', 'tweet_volume': None}, {'name': 'Pelicans', 'url': 'http://twitter.com/search?q=Pelicans', 'promoted_content': None, 'query': 'Pelicans', 'tweet_volume': 26953}, {'name': 'Chivas', 'url': 'http://twitter.com/search?q=Chivas', 'promoted_content': None, 'query': 'Chivas', 'tweet_volume': 41689}, {'name': 'HP 108MP 2jutaan', 'url': 'http://twitter.com/search?q=%22HP+108MP+2jutaan%22', 'promoted_content': None, 'query': '%22HP+108MP+2jutaan%22', 'tweet_volume': None}, {'name': 'San Lorenzo', 'url': 'http://twitter.com/search?q=%22San+Lorenzo%22', 'promoted_content': None, 'query': '%22San+Lorenzo%22', 'tweet_volume': 19928}, {'name': 'Prabowo Semakin Mantab', 'url': 'http://twitter.com/search?q=%22Prabowo+Semakin+Mantab%22', 'promoted_content': None, 'query': '%22Prabowo+Semakin+Mantab%22', 'tweet_volume': None}, {'name': 'Dipercaya Karena Kerjanya', 'url': 'http: ...
# *******************
# [{'trends': [{'name': '#TheKardashians', 'url': 'http://twitter.com/search?q=%23TheKardashians', 'promoted_content': None, 'query': '%23TheKardashians', 'tweet_volume': 15559}, {'name': 'Pelicans', 'url': 'http://twitter.com/search?q=Pelicans', 'promoted_content': None, 'query': 'Pelicans', 'tweet_volume': 26953}, {'name': '#SnowfallFX', 'url': 'http://twitter.com/search?q=%23SnowfallFX', 'promoted_content': None, 'query': '%23SnowfallFX', 'tweet_volume': 11340}, {'name': '#AEWDynamite', 'url': 'http://twitter.com/search?q=%23AEWDynamite', 'promoted_content': None, 'query': '%23AEWDynamite', 'tweet_volume': 74341}, {'name': 'Spurs', 'url': 'http://twitter.com/search?q=Spurs', 'promoted_content': None, 'query': 'Spurs', 'tweet_volume': 44338}, {'name': 'Daily Quordle 80', 'url': 'http://twitter.com/search?q=%22Daily+Quordle+80%22', 'promoted_content': None, 'query': '%22Daily+Quordle+80%22', 'tweet_volume': None}, {'name': '#dreamOUT', 'url': 'http://twitter.com/search?q=%23dreamOUT', 'promoted_content': None, 'query': '%23dreamOUT', 'tweet_volume': 17008}, {'name': '#GoAvsGo', 'url': 'http://twitter.com/search?q=%23GoAvsGo', 'promoted_content': None, 'query': '%23GoAvsGo', 'tweet_volume': None}, {'name': 'Herb Jones', 'url': 'http://twitter.com/search?q=%22Herb+Jones%22', 'promoted_content': None, 'query': '%22Herb+Jones%22', 'tweet_volume': None}, {'name': 'Moskva', 'url': 'http://twitter.com/search?q=Moskva', 'promoted_content': None, 'query': 'Moskva', 'tweet_volume': 143293}, {'name': 'CJ McCollum', 'url': 'http://twitter.com/search?q=%22CJ+McCollum%22', 'promoted_content': None, 'query': '%22CJ+McCollum%22', 'tweet_volume': None}, {'name': 'Pels', 'url': 'http://twitter.com/search?q=Pels', 'promoted_content': None, 'query': 'Pels', 'tweet_volume': 11355}, {'name': 'Black Sea', 'url': 'http://twitter.com/search?q=%22Black+Sea%22', 'promoted_content': None, 'query': '%22Black+Sea%22', 'tweet_volume': 74281}, {'name': 'Louie', 'url': 'http://twitter.com/search?q=Louie', 'promoted_content': None, 'query': 'Louie', 'tweet_volume': 16954}, {'name': 'Zion', 'url': 'http://twitter.com/search?q=Zion', 'promoted_content': None, 'query': 'Zion', 'tweet_volume': 21087}, {'name': 'Murray', 'url': 'http://twitter.com/search?q=Murray', 'promoted_content': None, 'query': 'Murray', 'tweet_volume': 17846}, {'name': 'Hornets', 'url': 'http://twitter.com/search?q=Hornets', 'promoted_content': None, 'query': 'Hornets', 'tweet_volume': 45834}, {'name': 'Spider-Man 3', 'url': 'http://twitter.com/search?q=%22Spider-Man+3%22', 'promoted_content': None, 'query': '%22Spider-Man+3%22', 'tweet_volume': None}, {'name': 'One Direction Heardle', 'url': 'http://twitter.com/search?q=%22One+Direction+Heardle%22', 'promoted_content': None, 'query': '%22One+Direction+Heardle%22', 'tweet_volume': None}, {'name': 'Ingram', 'url': 'http://twitter.com/search?q=Ingram', 'promoted_content': None, 'query': 'Ingram', 'tweet_volume': 10903}, {'name': 'Keldon', 'url': 'http://twitter.com/search?q=Keldon', 'promoted_content': None, 'query': 'Keldon', 'tweet_volume': None}, {'name': 'Hawks', 'url': 'http://twitter.com/search?q=Hawks', 'promoted_content': None, 'query': 'Hawks', 'tweet_volume': 40584}, {'name': 'Vassell', 'url': 'http://twitter.com/search?q=Vassell', 'promoted_content': None, 'query': 'Vassell', 'tweet_volume': None}, {'name': 'Jose Alvarado', 'url': 'http://twitter.com/search?q=%22Jose+Alvarado%22', 'promoted_content': None, 'query': '%22Jose+Alvarado%22', 'tweet_volume': None}, {'name': 'MacKinnon', 'url': 'http://twitter.com/search?q=MacKinnon', 'promoted_content': None, 'query': 'MacKinnon', 'tweet_volume': None}, {'name': 'Miles Bridges', 'url': 'http://twitter.com/search?q=%22Miles+Bridges%22', 'promoted_content': None, 'query': '%22Miles+Bridges%22', 'tweet_volume': None}, {'name': 'Freddy Rincón', 'url': 'http://twitter.com/search?q=%22Freddy+Rinc%C3%B3n%22', 'promoted_content': None, 'query': '%22Freddy+Rinc%C3%B3n%22', 'tweet_volume': 64001}, { ...

# %%
for trend in world_trends[0]['trends']:
    print(trend['name'])
# Out:
# #BamBamxโหนกระแส
# #AmbedkarJayanti
# Ret e L7
# Freddy Rincón
# Filipe Ret
# Rwanda
# #HalodocRamadan
# PA e Scooby
# #Baisakhi
# L7nnon
# #インターネット老人音楽祭
# インターネットのヲタク
# じゅじゅステ
# 三浦涼介
# 磯丸水産
# Daily Quordle 80
# Pelicans
# Chivas
# HP 108MP 2jutaan
# San Lorenzo
# Prabowo Semakin Mantab
# Dipercaya Karena Kerjanya
# Bangun Indonesia Tangguh
# ナナミン
# ENDYMION
# GUCCIの財布
# Water Fight With Patrick
# 五条先生
# luan city no bbb
# Coloso
# Matheus Fernandes
# Foto Malam Terbaik
# Indian Constitution
# OUR BELOVED HARUTO
# Leaño
# महावीर जयंती
# グリムグリモア
# Herb Jones
# あと2話
# 発売延期
# Willax
# Maundy Thursday
# りょんくん
# アイカツ
# ARTHUR AGUIAR NO YOUTUBE
# ユイナ先輩
# 9 pro
# Never Goodbye
# Happy New Year
# syudouさん

# %%
for trend in us_trends[0]['trends']:
    print(trend['name'])
# Out:
# #TheKardashians
# Pelicans
# #SnowfallFX
# #AEWDynamite
# Spurs
# Daily Quordle 80
# #dreamOUT
# #GoAvsGo
# Herb Jones
# Moskva
# CJ McCollum
# Pels
# Black Sea
# Louie
# Zion
# Murray
# Hornets
# Spider-Man 3
# One Direction Heardle
# Ingram
# Keldon
# Hawks
# Vassell
# Jose Alvarado
# MacKinnon
# Miles Bridges
# Freddy Rincón
# Vladdy
# Chivas
# TDKR
# Tabata
# john sterling
# Great Khali
# Willie Green
# The Dark Knight Rises
# Samoa Joe
# Frei
# makar
# Warchant
# Khloe
# The Avs
# Suzuki
# Neptune
# Lonnie
# poeltl
# Satnam Singh
# NYCFC
# Abbott Elementary
# Jethro Tull
# Popovich

# %% [markdown]
# - The pattern for using the twitter module is simple and predictable:
#     - instantiate the Twitter class with an object chain corresponding to a base URL and then invoke methods on the object that correspond to URL contexts.
#     - For example, twitter_api.trends_place(id=WORLD_WOE_ID) initiates an HTTP call to GET
#      https://api.twitter.com/1.1/trends/available.json
#     - Example "url": "http://where.yahooapis.com/v1/place/2458410",
#     - "woeid": 2458410
#    - https://api.twitter.com/1.1/trends/place.json?id=1.
#     - Note the URL mapping to the object chain that’s constructed with the twitter package to make the request and how query string parameters are passed in as keyword arguments.
#     - To use the twitter package for arbitrary API requests, you generally construct the request in that kind of straightforward manner.
#     - *** add more explanation **

# %% [markdown]
# **Example 1-3. Displaying API responses as pretty-printed JSON**

# %%
#Displaying API responses as pretty-printed JSON
#Please refer to the following link to understand the json.dumps feature more
#https://www.w3schools.com/python/python_json.asp
    
import json

print(json.dumps(world_trends, indent=1))
print()
print(json.dumps(us_trends, indent=1))
# Out:
# [
#  {
#   "trends": [
#    {
#     "name": "#BamBamx\u0e42\u0e2b\u0e19\u0e01\u0e23\u0e30\u0e41\u0e2a",
#     "url": "http://twitter.com/search?q=%23BamBamx%E0%B9%82%E0%B8%AB%E0%B8%99%E0%B8%81%E0%B8%A3%E0%B8%B0%E0%B9%81%E0%B8%AA",
#     "promoted_content": null,
#     "query": "%23BamBamx%E0%B9%82%E0%B8%AB%E0%B8%99%E0%B8%81%E0%B8%A3%E0%B8%B0%E0%B9%81%E0%B8%AA",
#     "tweet_volume": 374871
#    },
#    {
#     "name": "#AmbedkarJayanti",
#     "url": "http://twitter.com/search?q=%23AmbedkarJayanti",
#     "promoted_content": null,
#     "query": "%23AmbedkarJayanti",
#     "tweet_volume": 133782
#    },
#    {
#     "name": "Ret e L7",
#     "url": "http://twitter.com/search?q=%22Ret+e+L7%22",
#     "promoted_content": null,
#     "query": "%22Ret+e+L7%22",
#     "tweet_volume": 43453
#    },
#    {
#     "name": "Freddy Rinc\u00f3n",
#     "url": "http://twitter.com/search?q=%22Freddy+Rinc%C3%B3n%22",
#     "promoted_content": null,
#     "query": "%22Freddy+Rinc%C3%B3n%22",
#     "tweet_volume": 64001
#    },
#    {
#     "name": "Filipe Ret",
#     "url": "http://twitter.com/search?q=%22Filipe+Ret%22",
#     "promoted_content": null,
#     "query": "%22Filipe+Ret%22",
#     "tweet_volume": 28765
#    },
#    {
#     "name": "Rwanda",
#     "url": "http://twitter.com/search?q=Rwanda",
#     "promoted_content": null,
#     "query": "Rwanda",
#     "tweet_volume": 50105
#    },
#    {
#     "name": "#HalodocRamadan",
#     "url": "http://twitter.com/search?q=%23HalodocRamadan",
#     "promoted_content": null,
#     "query": "%23HalodocRamadan",
#     "tweet_volume": null
#    },
#    {
#     "name": "PA e Scooby",
#     "url": "http://twitter.com/search?q=%22PA+e+Scooby%22",
#     "promoted_content": null,
#     "query": "%22PA+e+Scooby%22",
#     "tweet_volume": 27273
#    },
#    {
#     "name": "#Baisakhi",
#     "url": "http://twitter.com/search?q=%23Baisakhi",
#     "promoted_content": null,
#     "query": "%23Baisakhi",
#     "tweet_volume": 10817
#    },
#    {
#     "name": "L7nnon",
#     "url": "http://twitter.com/search?q=L7nnon",
#     "promoted_content": null,
#     "query": "L7nnon",
#     "tweet_volume": 18224
#    },
#    {
#     "name": "#\u30a4\u30f3\u30bf\u30fc\u30cd\u30c3\u30c8\u8001\u4eba\u97f3\u697d\u796d",
#     "url": "http://twitter.com/search?q=%23%E3%82%A4%E3%83%B3%E3%82%BF%E3%83%BC%E3%83%8D%E3%83%83%E3%83%88%E8%80%81%E4%BA%BA%E9%9F%B3%E6%A5%BD%E7%A5%AD",
#     "promoted_content": null,
#     "query": "%23%E3%82%A4%E3%83%B3%E3%82%BF%E3%83%BC%E3%83%8D%E3%83%83%E3%83%88%E8%80%81%E4%BA%BA%E9%9F%B3%E6%A5%BD%E7%A5%AD",
#     "tweet_volume": null
#    },
#    {
#     "name": "\u30a4\u30f3\u30bf\u30fc\u30cd\u30c3\u30c8\u306e\u30f2\u30bf\u30af",
#     "url": "http://twitter.com/search?q=%E3%82%A4%E3%83%B3%E3%82%BF%E3%83%BC%E3%83%8D%E3%83%83%E3%83%88%E3%81%AE%E3%83%B2%E3%82%BF%E3%82%AF",
#     "promoted_content": null,
#     "query": "%E3%82%A4%E3%83%B3%E3%82%BF%E3%83%BC%E3%83%8D%E3%83%83%E3%83%88%E3%81%AE%E3%83%B2%E3%82%BF%E3%82%AF",
#     "tweet_volume": null
#    },
#    {
#     "name": "\u3058\u3085\u3058\u3085\u30b9\u30c6",
#     "url": "http://twitter.com/search?q=%E3%81%98%E3%82%85%E3%81%98%E3%82%85%E3%82%B9%E3%83%86",
#     "promoted_content": null,
#     "query": "%E3%81%98%E3%82%85%E3%81%98%E3%82%85%E3%82%B9%E3%83%86",
#     "tweet_volume": null
#    },
#    {
#     "name": "\u4e09\u6d66\u6dbc\u4ecb",
#     "url": "http://twitter.com/search?q=%E4%B8%89%E6%B5%A6%E6%B6%BC%E4%BB%8B",
#     "promoted_content": null,
#     "query": "%E4%B8%89%E6%B5%A6%E6%B6%BC%E4%BB%8B",
#     "tweet_volume": 34737
#    },
#    {
#     "name": "\u78ef\u4e38\u6c34\u7523",
#     "url": "http://twitter.com/search?q=%E7%A3%AF%E4%B8%B8%E6%B0%B4%E7%94%A3",
#     "promoted_content": null,
#     "query": "%E7%A3%AF%E4%B8%B8%E6%B0%B4%E7%94%A3",
#     "tweet_volume": null
#    },
#    {
#     "name": "Daily Quordle 80",
#     "url": "http://twitter.com/search?q=%22Daily+Quordle+80%22",
#     "promoted_content": null,
#     "query": "%22Daily+Quordle+80%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Pelicans",
#     "url": "http://twitter.com/search?q=Pelicans",
#     "promoted_content": null,
#     "query": "Pelicans",
#     "tweet_volume": 26953
#    },
#    {
#     "name": "Chivas",
#     "url": "http://twitter.com/search?q=Chivas",
#     "promoted_content": null,
#     "query": "Chivas",
#     "tweet_volume": 41689
#    },
#    {
#     "name": "HP 108MP 2jutaan",
#     "url": "http://twitter.com/search?q=%22HP+108MP+2jutaan%22",
#     "promoted_content": null,
#     "query": "%22HP+108MP+2jutaan%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "San Lorenzo",
#     "url": "http://twitter.com/search?q=%22San+Lorenzo%22",
#     "promoted_content": null,
#     "query": "%22San+Lorenzo%22",
#     "tweet_volume": 19928
#    },
#    {
#     "name": "Prabowo Semakin Mantab",
#     "url": "http://twitter.com/search?q=%22Prabowo+Semakin+Mantab%22",
#     "promoted_content": null,
#     "query": "%22Prabowo+Semakin+Mantab%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Dipercaya Karena Kerjanya",
#     "url": "http://twitter.com/search?q=%22Dipercaya+Karena+Kerjanya%22",
#     "promoted_content": null,
#     "query": "%22Dipercaya+Karena+Kerjanya%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Bangun Indonesia Tangguh",
#     "url": "http://twitter.com/search?q=%22Bangun+Indonesia+Tangguh%22",
#     "promoted_content": null,
#     "query": "%22Bangun+Indonesia+Tangguh%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "\u30ca\u30ca\u30df\u30f3",
#     "url": "http://twitter.com/search?q=%E3%83%8A%E3%83%8A%E3%83%9F%E3%83%B3",
#     "promoted_content": null,
#     "query": "%E3%83%8A%E3%83%8A%E3%83%9F%E3%83%B3",
#     "tweet_volume": null
#    },
#    {
#     "name": "ENDYMION",
#     "url": "http://twitter.com/search?q=ENDYMION",
#     "promoted_content": null,
#     "query": "ENDYMION",
#     "tweet_volume": 11947
#    },
#    {
#     "name": "GUCCI\u306e\u8ca1\u5e03",
#     "url": "http://twitter.com/search?q=GUCCI%E3%81%AE%E8%B2%A1%E5%B8%83",
#     "promoted_content": null,
#     "query": "GUCCI%E3%81%AE%E8%B2%A1%E5%B8%83",
#     "tweet_volume": null
#    },
#    {
#     "name": "Water Fight With Patrick",
#     "url": "http://twitter.com/search?q=%22Water+Fight+With+Patrick%22",
#     "promoted_content": null,
#     "query": "%22Water+Fight+With+Patrick%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "\u4e94\u6761\u5148\u751f",
#     "url": "http://twitter.com/search?q=%E4%BA%94%E6%9D%A1%E5%85%88%E7%94%9F",
#     "promoted_content": null,
#     "query": "%E4%BA%94%E6%9D%A1%E5%85%88%E7%94%9F",
#     "tweet_volume": null
#    },
#    {
#     "name": "luan city no bbb",
#     "url": "http://twitter.com/search?q=%22luan+city+no+bbb%22",
#     "promoted_content": null,
#     "query": "%22luan+city+no+bbb%22",
#     "tweet_volume": 20059
#    },
#    {
#     "name": "Coloso",
#     "url": "http://twitter.com/search?q=Coloso",
#     "promoted_content": null,
#     "query": "Coloso",
#     "tweet_volume": 10177
#    },
#    {
#     "name": "Matheus Fernandes",
#     "url": "http://twitter.com/search?q=%22Matheus+Fernandes%22",
#     "promoted_content": null,
#     "query": "%22Matheus+Fernandes%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Foto Malam Terbaik",
#     "url": "http://twitter.com/search?q=%22Foto+Malam+Terbaik%22",
#     "promoted_content": null,
#     "query": "%22Foto+Malam+Terbaik%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Indian Constitution",
#     "url": "http://twitter.com/search?q=%22Indian+Constitution%22",
#     "promoted_content": null,
#     "query": "%22Indian+Constitution%22",
#     "tweet_volume": 15663
#    },
#    {
#     "name": "OUR BELOVED HARUTO",
#     "url": "http://twitter.com/search?q=%22OUR+BELOVED+HARUTO%22",
#     "promoted_content": null,
#     "query": "%22OUR+BELOVED+HARUTO%22",
#     "tweet_volume": 13918
#    },
#    {
#     "name": "Lea\u00f1o",
#     "url": "http://twitter.com/search?q=Lea%C3%B1o",
#     "promoted_content": null,
#     "query": "Lea%C3%B1o",
#     "tweet_volume": null
#    },
#    {
#     "name": "\u092e\u0939\u093e\u0935\u0940\u0930 \u091c\u092f\u0902\u0924\u0940",
#     "url": "http://twitter.com/search?q=%22%E0%A4%AE%E0%A4%B9%E0%A4%BE%E0%A4%B5%E0%A5%80%E0%A4%B0+%E0%A4%9C%E0%A4%AF%E0%A4%82%E0%A4%A4%E0%A5%80%22",
#     "promoted_content": null,
#     "query": "%22%E0%A4%AE%E0%A4%B9%E0%A4%BE%E0%A4%B5%E0%A5%80%E0%A4%B0+%E0%A4%9C%E0%A4%AF%E0%A4%82%E0%A4%A4%E0%A5%80%22",
#     "tweet_volume": 45559
#    },
#    {
#     "name": "\u30b0\u30ea\u30e0\u30b0\u30ea\u30e2\u30a2",
#     "url": "http://twitter.com/search?q=%E3%82%B0%E3%83%AA%E3%83%A0%E3%82%B0%E3%83%AA%E3%83%A2%E3%82%A2",
#     "promoted_content": null,
#     "query": "%E3%82%B0%E3%83%AA%E3%83%A0%E3%82%B0%E3%83%AA%E3%83%A2%E3%82%A2",
#     "tweet_volume": null
#    },
#    {
#     "name": "Herb Jones",
#     "url": "http://twitter.com/search?q=%22Herb+Jones%22",
#     "promoted_content": null,
#     "query": "%22Herb+Jones%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "\u3042\u30682\u8a71",
#     "url": "http://twitter.com/search?q=%E3%81%82%E3%81%A82%E8%A9%B1",
#     "promoted_content": null,
#     "query": "%E3%81%82%E3%81%A82%E8%A9%B1",
#     "tweet_volume": null
#    },
#    {
#     "name": "\u767a\u58f2\u5ef6\u671f",
#     "url": "http://twitter.com/search?q=%E7%99%BA%E5%A3%B2%E5%BB%B6%E6%9C%9F",
#     "promoted_content": null,
#     "query": "%E7%99%BA%E5%A3%B2%E5%BB%B6%E6%9C%9F",
#     "tweet_volume": null
#    },
#    {
#     "name": "Willax",
#     "url": "http://twitter.com/search?q=Willax",
#     "promoted_content": null,
#     "query": "Willax",
#     "tweet_volume": 19716
#    },
#    {
#     "name": "Maundy Thursday",
#     "url": "http://twitter.com/search?q=%22Maundy+Thursday%22",
#     "promoted_content": null,
#     "query": "%22Maundy+Thursday%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "\u308a\u3087\u3093\u304f\u3093",
#     "url": "http://twitter.com/search?q=%E3%82%8A%E3%82%87%E3%82%93%E3%81%8F%E3%82%93",
#     "promoted_content": null,
#     "query": "%E3%82%8A%E3%82%87%E3%82%93%E3%81%8F%E3%82%93",
#     "tweet_volume": null
#    },
#    {
#     "name": "\u30a2\u30a4\u30ab\u30c4",
#     "url": "http://twitter.com/search?q=%E3%82%A2%E3%82%A4%E3%82%AB%E3%83%84",
#     "promoted_content": null,
#     "query": "%E3%82%A2%E3%82%A4%E3%82%AB%E3%83%84",
#     "tweet_volume": 21066
#    },
#    {
#     "name": "ARTHUR AGUIAR NO YOUTUBE",
#     "url": "http://twitter.com/search?q=%22ARTHUR+AGUIAR+NO+YOUTUBE%22",
#     "promoted_content": null,
#     "query": "%22ARTHUR+AGUIAR+NO+YOUTUBE%22",
#     "tweet_volume": 264051
#    },
#    {
#     "name": "\u30e6\u30a4\u30ca\u5148\u8f29",
#     "url": "http://twitter.com/search?q=%E3%83%A6%E3%82%A4%E3%83%8A%E5%85%88%E8%BC%A9",
#     "promoted_content": null,
#     "query": "%E3%83%A6%E3%82%A4%E3%83%8A%E5%85%88%E8%BC%A9",
#     "tweet_volume": null
#    },
#    {
#     "name": "9 pro",
#     "url": "http://twitter.com/search?q=%229+pro%22",
#     "promoted_content": null,
#     "query": "%229+pro%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Never Goodbye",
#     "url": "http://twitter.com/search?q=%22Never+Goodbye%22",
#     "promoted_content": null,
#     "query": "%22Never+Goodbye%22",
#     "tweet_volume": 25238
#    },
#    {
#     "name": "Happy New Year",
#     "url": "http://twitter.com/search?q=%22Happy+New+Year%22",
#     "promoted_content": null,
#     "query": "%22Happy+New+Year%22",
#     "tweet_volume": 46621
#    },
#    {
#     "name": "syudou\u3055\u3093",
#     "url": "http://twitter.com/search?q=syudou%E3%81%95%E3%82%93",
#     "promoted_content": null,
#     "query": "syudou%E3%81%95%E3%82%93",
#     "tweet_volume": null
#    }
#   ],
#   "as_of": "2022-04-14T06:42:49Z",
#   "created_at": "2022-04-13T04:03:38Z",
#   "locations": [
#    {
#     "name": "Worldwide",
#     "woeid": 1
#    }
#   ]
#  }
# ]
#
# [
#  {
#   "trends": [
#    {
#     "name": "#TheKardashians",
#     "url": "http://twitter.com/search?q=%23TheKardashians",
#     "promoted_content": null,
#     "query": "%23TheKardashians",
#     "tweet_volume": 15559
#    },
#    {
#     "name": "Pelicans",
#     "url": "http://twitter.com/search?q=Pelicans",
#     "promoted_content": null,
#     "query": "Pelicans",
#     "tweet_volume": 26953
#    },
#    {
#     "name": "#SnowfallFX",
#     "url": "http://twitter.com/search?q=%23SnowfallFX",
#     "promoted_content": null,
#     "query": "%23SnowfallFX",
#     "tweet_volume": 11340
#    },
#    {
#     "name": "#AEWDynamite",
#     "url": "http://twitter.com/search?q=%23AEWDynamite",
#     "promoted_content": null,
#     "query": "%23AEWDynamite",
#     "tweet_volume": 74341
#    },
#    {
#     "name": "Spurs",
#     "url": "http://twitter.com/search?q=Spurs",
#     "promoted_content": null,
#     "query": "Spurs",
#     "tweet_volume": 44338
#    },
#    {
#     "name": "Daily Quordle 80",
#     "url": "http://twitter.com/search?q=%22Daily+Quordle+80%22",
#     "promoted_content": null,
#     "query": "%22Daily+Quordle+80%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "#dreamOUT",
#     "url": "http://twitter.com/search?q=%23dreamOUT",
#     "promoted_content": null,
#     "query": "%23dreamOUT",
#     "tweet_volume": 17008
#    },
#    {
#     "name": "#GoAvsGo",
#     "url": "http://twitter.com/search?q=%23GoAvsGo",
#     "promoted_content": null,
#     "query": "%23GoAvsGo",
#     "tweet_volume": null
#    },
#    {
#     "name": "Herb Jones",
#     "url": "http://twitter.com/search?q=%22Herb+Jones%22",
#     "promoted_content": null,
#     "query": "%22Herb+Jones%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Moskva",
#     "url": "http://twitter.com/search?q=Moskva",
#     "promoted_content": null,
#     "query": "Moskva",
#     "tweet_volume": 143293
#    },
#    {
#     "name": "CJ McCollum",
#     "url": "http://twitter.com/search?q=%22CJ+McCollum%22",
#     "promoted_content": null,
#     "query": "%22CJ+McCollum%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Pels",
#     "url": "http://twitter.com/search?q=Pels",
#     "promoted_content": null,
#     "query": "Pels",
#     "tweet_volume": 11355
#    },
#    {
#     "name": "Black Sea",
#     "url": "http://twitter.com/search?q=%22Black+Sea%22",
#     "promoted_content": null,
#     "query": "%22Black+Sea%22",
#     "tweet_volume": 74281
#    },
#    {
#     "name": "Louie",
#     "url": "http://twitter.com/search?q=Louie",
#     "promoted_content": null,
#     "query": "Louie",
#     "tweet_volume": 16954
#    },
#    {
#     "name": "Zion",
#     "url": "http://twitter.com/search?q=Zion",
#     "promoted_content": null,
#     "query": "Zion",
#     "tweet_volume": 21087
#    },
#    {
#     "name": "Murray",
#     "url": "http://twitter.com/search?q=Murray",
#     "promoted_content": null,
#     "query": "Murray",
#     "tweet_volume": 17846
#    },
#    {
#     "name": "Hornets",
#     "url": "http://twitter.com/search?q=Hornets",
#     "promoted_content": null,
#     "query": "Hornets",
#     "tweet_volume": 45834
#    },
#    {
#     "name": "Spider-Man 3",
#     "url": "http://twitter.com/search?q=%22Spider-Man+3%22",
#     "promoted_content": null,
#     "query": "%22Spider-Man+3%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "One Direction Heardle",
#     "url": "http://twitter.com/search?q=%22One+Direction+Heardle%22",
#     "promoted_content": null,
#     "query": "%22One+Direction+Heardle%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Ingram",
#     "url": "http://twitter.com/search?q=Ingram",
#     "promoted_content": null,
#     "query": "Ingram",
#     "tweet_volume": 10903
#    },
#    {
#     "name": "Keldon",
#     "url": "http://twitter.com/search?q=Keldon",
#     "promoted_content": null,
#     "query": "Keldon",
#     "tweet_volume": null
#    },
#    {
#     "name": "Hawks",
#     "url": "http://twitter.com/search?q=Hawks",
#     "promoted_content": null,
#     "query": "Hawks",
#     "tweet_volume": 40584
#    },
#    {
#     "name": "Vassell",
#     "url": "http://twitter.com/search?q=Vassell",
#     "promoted_content": null,
#     "query": "Vassell",
#     "tweet_volume": null
#    },
#    {
#     "name": "Jose Alvarado",
#     "url": "http://twitter.com/search?q=%22Jose+Alvarado%22",
#     "promoted_content": null,
#     "query": "%22Jose+Alvarado%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "MacKinnon",
#     "url": "http://twitter.com/search?q=MacKinnon",
#     "promoted_content": null,
#     "query": "MacKinnon",
#     "tweet_volume": null
#    },
#    {
#     "name": "Miles Bridges",
#     "url": "http://twitter.com/search?q=%22Miles+Bridges%22",
#     "promoted_content": null,
#     "query": "%22Miles+Bridges%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Freddy Rinc\u00f3n",
#     "url": "http://twitter.com/search?q=%22Freddy+Rinc%C3%B3n%22",
#     "promoted_content": null,
#     "query": "%22Freddy+Rinc%C3%B3n%22",
#     "tweet_volume": 64001
#    },
#    {
#     "name": "Vladdy",
#     "url": "http://twitter.com/search?q=Vladdy",
#     "promoted_content": null,
#     "query": "Vladdy",
#     "tweet_volume": 17943
#    },
#    {
#     "name": "Chivas",
#     "url": "http://twitter.com/search?q=Chivas",
#     "promoted_content": null,
#     "query": "Chivas",
#     "tweet_volume": 41682
#    },
#    {
#     "name": "TDKR",
#     "url": "http://twitter.com/search?q=TDKR",
#     "promoted_content": null,
#     "query": "TDKR",
#     "tweet_volume": null
#    },
#    {
#     "name": "Tabata",
#     "url": "http://twitter.com/search?q=Tabata",
#     "promoted_content": null,
#     "query": "Tabata",
#     "tweet_volume": null
#    },
#    {
#     "name": "john sterling",
#     "url": "http://twitter.com/search?q=%22john+sterling%22",
#     "promoted_content": null,
#     "query": "%22john+sterling%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Great Khali",
#     "url": "http://twitter.com/search?q=%22Great+Khali%22",
#     "promoted_content": null,
#     "query": "%22Great+Khali%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Willie Green",
#     "url": "http://twitter.com/search?q=%22Willie+Green%22",
#     "promoted_content": null,
#     "query": "%22Willie+Green%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "The Dark Knight Rises",
#     "url": "http://twitter.com/search?q=%22The+Dark+Knight+Rises%22",
#     "promoted_content": null,
#     "query": "%22The+Dark+Knight+Rises%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Samoa Joe",
#     "url": "http://twitter.com/search?q=%22Samoa+Joe%22",
#     "promoted_content": null,
#     "query": "%22Samoa+Joe%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Frei",
#     "url": "http://twitter.com/search?q=Frei",
#     "promoted_content": null,
#     "query": "Frei",
#     "tweet_volume": 13176
#    },
#    {
#     "name": "makar",
#     "url": "http://twitter.com/search?q=makar",
#     "promoted_content": null,
#     "query": "makar",
#     "tweet_volume": null
#    },
#    {
#     "name": "Warchant",
#     "url": "http://twitter.com/search?q=Warchant",
#     "promoted_content": null,
#     "query": "Warchant",
#     "tweet_volume": null
#    },
#    {
#     "name": "Khloe",
#     "url": "http://twitter.com/search?q=Khloe",
#     "promoted_content": null,
#     "query": "Khloe",
#     "tweet_volume": null
#    },
#    {
#     "name": "The Avs",
#     "url": "http://twitter.com/search?q=%22The+Avs%22",
#     "promoted_content": null,
#     "query": "%22The+Avs%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Suzuki",
#     "url": "http://twitter.com/search?q=Suzuki",
#     "promoted_content": null,
#     "query": "Suzuki",
#     "tweet_volume": 31612
#    },
#    {
#     "name": "Neptune",
#     "url": "http://twitter.com/search?q=Neptune",
#     "promoted_content": null,
#     "query": "Neptune",
#     "tweet_volume": 38715
#    },
#    {
#     "name": "Lonnie",
#     "url": "http://twitter.com/search?q=Lonnie",
#     "promoted_content": null,
#     "query": "Lonnie",
#     "tweet_volume": null
#    },
#    {
#     "name": "poeltl",
#     "url": "http://twitter.com/search?q=poeltl",
#     "promoted_content": null,
#     "query": "poeltl",
#     "tweet_volume": null
#    },
#    {
#     "name": "Satnam Singh",
#     "url": "http://twitter.com/search?q=%22Satnam+Singh%22",
#     "promoted_content": null,
#     "query": "%22Satnam+Singh%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "NYCFC",
#     "url": "http://twitter.com/search?q=NYCFC",
#     "promoted_content": null,
#     "query": "NYCFC",
#     "tweet_volume": null
#    },
#    {
#     "name": "Abbott Elementary",
#     "url": "http://twitter.com/search?q=%22Abbott+Elementary%22",
#     "promoted_content": null,
#     "query": "%22Abbott+Elementary%22",
#     "tweet_volume": 32587
#    },
#    {
#     "name": "Jethro Tull",
#     "url": "http://twitter.com/search?q=%22Jethro+Tull%22",
#     "promoted_content": null,
#     "query": "%22Jethro+Tull%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Popovich",
#     "url": "http://twitter.com/search?q=Popovich",
#     "promoted_content": null,
#     "query": "Popovich",
#     "tweet_volume": null
#    }
#   ],
#   "as_of": "2022-04-14T06:42:49Z",
#   "created_at": "2022-04-12T14:06:20Z",
#   "locations": [
#    {
#     "name": "United States",
#     "woeid": 23424977
#    }
#   ]
#  }
# ]

# %% [markdown]
# **Example 1-4**
# - Demonstrates how to use a Python list comprehension to parse out the names of the trending topics from the results that were previously queried, cast those lists to sets, and compute the setwise intersection to reveal the common items between them.
# - Please refere to the following link to understand list comprehension more
# - https://docs.python.org/2/tutorial/datastructures.html#list-comprehensions

# %%
world_trends_set = set([trend['name'] 
                        for trend in world_trends[0]['trends']])

us_trends_set = set([trend['name'] 
                     for trend in us_trends[0]['trends']]) 

common_trends = world_trends_set.intersection(us_trends_set)

print(common_trends)
# Out:
# {'Freddy Rincón', 'Pelicans', 'Daily Quordle 80', 'Chivas', 'Herb Jones'}
